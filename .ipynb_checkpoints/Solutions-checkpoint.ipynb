# %% [markdown]
# # Random Forest Classifiers solutions
#
# Last week for the Decision Tree Classifiers problem set we worked with the white wine dataset. This week, we will be using the red wine dataset, and you could even use the white wine dataset to compare how the random forest classifier compares to the output from the decision tree classifier.
#
# This problem set is based on the workflow demonstrated in the workshop and so most of the answers can be found there.
#
# We will begin with exploring the data, showing how the data is distributed and how the classifications are created. After that, there are several different problems, some asking you to fill in the piece of code, others asking you to write the code yourself.
#
# # Data Exploration
#
# We will begin by importing the data and exploring what it contains. It is worth thinking about how this data differs to the NBA dataset introduced in the workshop, and how this may influence how well the analysis will perform.

# %%
#import the relevant libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read in the data
red_wine = pd.read_csv("Data/Red_wine.csv", sep=";")

# %%
#check to see what format the data is in
print("Rows, columns: " +str(red_wine.shape))
# Out:
# Rows, columns: (1599, 12)

# %%
#Check to see what is in the first 5 rows
red_wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#check to see what is in the last 5 rows
red_wine.tail(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
#extract summary statistics of the data
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Now that you have seen a small overview of the data, what does this tell you and what do you think an analysis using random forests would extract from this? Is there anything you can extract already.
#
# Given that this dataset is about iwne quality, we need to udnerstand and visualise our dependent variable, which is wine quality.
#
# We can do this with a histogram to examine the distribution of quality ratings. What can you see from this plot? Can you think about how this would influence our analysis?

# %%
fig, ax = plt.subplots(figsize=(10,10))

red_wine.quality.hist()
ax.set_title("White wine quality ratings", fontsize = 20)
ax.set_ylabel("Frequency", fontsize =20)
ax.set_xlabel("Quality", fontsize = 20)
# Out:
# Text(0.5, 0, 'Quality')

# %% [markdown]
# Given that this is our dependent variable, we want to see how other factros may be correlated with this, and how the independent factors may be related to each other. We can do this using a correlation matrix.
#
# Can see any factors that are strongly correlated with wine quality?
#
# - How do you think this will influence the results?
# - How would this play out in the decision tree?
# - How would factors that are correlated with each other influence the random forest?

# %%
corr = red_wine.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,
           annot = True, cmap ="magma")
ax.set_title("Correlation plot of wine quality")
# Out:
# Text(0.5, 1.0, 'Correlation plot of wine quality')

# %% [markdown]
# For our purpose, we want to create classifications which our random forest can aim for. Here, we will define good quality wine as scoring 7 or over, okay quality as 6 and bad quality as 5 or less.
#
# How do you think this will influence the results?

# %%
def qual_check(x):
    if x >= 7:
        return "good"
    if x == 6:
        return "okay"
    else:
        return "bad"


red_wine["quality"] = red_wine["quality"].apply(qual_check)

# %%
red_wine.quality.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Setting up the data
#
# To create the random forest, we need to extract our dependent and independent variables i.e. what are we using the random forest to predict?
#
# Fill in the ??

# %%
X = red_wine.drop(columns ="quality")
y = red_wine.quality

# %%
feature_names = X.columns
labels = y.unique()

# %% [markdown]
# The next thing to do is to split the data, what function to we need to import for that?

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# We want to create the test size of 25%, how do we set that up?

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3,
                                                     random_state = 42)

# %% [markdown]
# # Creating the dummy classifier
#
# One of the first thing we want to do is to import the dummy classifier so we can compare our results to it to see if the decision has improved.
#
# What libaries do we need to import?

# %%
#The dummy classifier
from sklearn.dummy import DummyClassifier
#the metrics
from sklearn import metrics

# %% [markdown]
# What strategy do we want to apply to the dummy classifier?

# %%
dc = DummyClassifier(strategy='most_frequent',
                    random_state = 42)
dc.fit(X_train,y_train) 
dc_preds = dc.predict(X_test)

# %% [markdown]
# How do we print out the metric results?

# %%
print (metrics.classification_report(y_test, dc_preds))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.44      1.00      0.61       213
#         good       0.00      0.00      0.00        67
#         okay       0.00      0.00      0.00       200
#
#     accuracy                           0.44       480
#    macro avg       0.15      0.33      0.20       480
# weighted avg       0.20      0.44      0.27       480
# C:\Users\phili\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Creating the actual classifier
#
# Then we want to create the actual Random Forest Classiffier, with 100 estimates, oob_score and max depth of 3. Can you crate import the correct classifier and set it up?

# %%
#import the classifier
from sklearn.ensemble import RandomForestClassifier

#create the classifier
clf = RandomForestClassifier(n_estimators =100, oob_score=True, max_depth =3,
                            random_state = 42)

# %% [markdown]
# Then fit it to the data

# %%
#fit it to the training data
clf.fit(X_train, y_train)
#extract the predictions
test_pred_random_forest = clf.predict(X_test)

# %%
y_test.value_counts()
# Out:
# bad     213
# okay    200
# good     67
# Name: quality, dtype: int64

# %% [markdown]
# Create the confusion matrix

# %%
# get the confusion matrix
confusion_matrix2 = metrics.confusion_matrix(y_test, test_pred_random_forest)
confusion_matrix2
# Out:
# array([[171,   1,  41],
#        [  3,   8,  56],
#        [ 94,   4, 102]], dtype=int64)

# %%
matrix2_df = pd.DataFrame(confusion_matrix2)

# set axis to add title and axis labels later
ax = plt.axes()
sns.set(font_scale=1.3) # for label size
plt.figure(figsize=(12,12))

plot = sns.heatmap(matrix2_df, annot=True, fmt='g', ax=ax, cmap = "magma") #fmt so that numbers aren't scientific

#axis labels and title
ax.set_title('Confusion Matrix - Random Forest', fontsize = 17)
ax.set_xlabel('Predicted Label', fontsize = 15)
ax.set_ylabel('True Label'     , fontsize = 15)

CM_labels = ["bad", "good", "okay"]
ax.set_xticklabels(CM_labels, fontsize = 15)
ax.set_yticklabels(CM_labels, fontsize = 15)
plt.show()

# %% [markdown]
# What does this tell us?
#
# We then want to plot some trees. fill in the ??

# %%
from sklearn import tree

import numpy as np
a = np.array(y_test.unique())
a = a.astype('<U10')
a

for x in range (45, 50):
    fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=800)
    tree.plot_tree(clf.estimators_[x],
                   feature_names = feature_names, 
                   class_names = a,
                   filled = True);

# %% [markdown]
# How do we get different scores? What do these mean?

# %%
train_accuracy = clf.score(X_train, y_train)
test_accuracy = clf.score(X_test, y_test)
oob_score = clf.oob_score_

print(f"The training score of the random forest classifier is : {train_accuracy:.3f}")
print(f"The out of basket score is: {oob_score:.3f}")
print(f"The test score of the random forest classifier is {test_accuracy:.3f}")
# Out:
# The training score of the random forest classifier is : 0.672
# The out of basket score is: 0.645
# The test score of the random forest classifier is 0.585

# %% [markdown]
# How can we extract metrics such as precision, recall and f1 score in a single table?

# %%
from sklearn import metrics

print (metrics.classification_report(y_test, test_pred_random_forest))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.64      0.80      0.71       213
#         good       0.62      0.12      0.20        67
#         okay       0.51      0.51      0.51       200
#
#     accuracy                           0.59       480
#    macro avg       0.59      0.48      0.47       480
# weighted avg       0.58      0.59      0.56       480

# %% [markdown]
# We can compare this to our Dummy Classifier that we created earlier.
#
# How much has the accuracy improved?
#
# Why has this improved?
#
# What can we learn from this?

# %% [markdown]
# # Feature importance
#
# Remember what we learnt in the workshop. A good thing about Random Forest Classifiers as compared to a isngle decision tree is that we can examine feature importance more closely.
#
# Why can we do this?
#
# What is the importance of this?
#
# Can you fill in the code to produce the feature importance plot?

# %%
#print(clf.feature_importances_)
fi = pd.DataFrame({'feature': list(X.columns),
                  'importance': clf.feature_importances_}).\
                    sort_values('importance', ascending=True)

plot = fi.plot.barh(x = 'feature', y = 'importance', figsize=(15,15))
plot.set_ylabel("Features")
plot.set_xlabel("Importance")

fig = plot.get_figure()
#fig.savefig("Plots/feature_importance_rf.png", bbox_inches='tight')

# %% [markdown]
# Can you extract any features that have an importance that is less than 2%?

# %%
fi[fi.importance <= 0.02]
# Out:
#                feature  importance
# 5  free sulfur dioxide    0.011230
# 8                   pH    0.011328
# 0        fixed acidity    0.016422
# 3       residual sugar    0.018474

# %% [markdown]
# Can you calculate the permutation importance?

# %%
from sklearn.metrics import r2_score
from sklearn.inspection import permutation_importance


result = permutation_importance(clf, X_test, y_test, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()

fig, ax = plt.subplots(figsize=(15,15))
ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=X_test.columns[sorted_idx])
ax.set_ylabel("Features")
ax.set_title("Permutation Importances (test set)")
fig.tight_layout()
plt.show()

# %% [markdown]
# Can you remove features that have less than 2% importance and train the model again? How has the outcome changed?

# %%
#extracting unimportant features
UIF = list(fi[fi.importance <= 0.02].feature)

X_trainIF = X_train.drop(columns = UIF)
X_testIF = X_test.drop(columns = UIF)

clf.fit(X_trainIF, y_train)
test_pred_random_forest_IF = clf.predict(X_testIF)

train_accuracy = clf.score(X_trainIF, y_train)
test_accuracy = clf.score(X_testIF, y_test)
oob_score = clf.oob_score_

print(f"The training score of the random forest classifier is : {train_accuracy:.3f}")
print(f"The out of basket score is: {oob_score:.3f}")
print(f"The test score of the random forest classifier is {test_accuracy:.3f}\n\n")

print (metrics.classification_report(y_test, test_pred_random_forest_IF))
# Out:
# The training score of the random forest classifier is : 0.672
# The out of basket score is: 0.643
# The test score of the random forest classifier is 0.594
#
#
#               precision    recall  f1-score   support
#
#          bad       0.65      0.80      0.72       213
#         good       0.67      0.12      0.20        67
#         okay       0.52      0.54      0.53       200
#
#     accuracy                           0.59       480
#    macro avg       0.61      0.48      0.48       480
# weighted avg       0.60      0.59      0.57       480

# %% [markdown]
# # Tune the hyperparameters
#
# We originally set the max depth as 3. Can you create a grid search to find the max depth that creates the most accuracy within the range of 3-10?

# %%
from sklearn.model_selection import GridSearchCV

tuned_parameters = [{'max_depth': [3,4,5,6,7,8,9,10]}]

scores = ['accuracy']

for score in scores:
    
    print()
    print(f"Tuning hyperparameters for {score}")
    print()
    
    clf = GridSearchCV(
        RandomForestClassifier(), tuned_parameters,
        scoring = f'{score}'
    )
    clf.fit(X_trainIF, y_train)
    
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    means = clf.cv_results_["mean_test_score"]
    stds = clf.cv_results_["std_test_score"]
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print(f"{mean:0.3f} (+/-{std*2:0.03f}) for {params}")
# Out:
# Tuning hyperparameters for accuracy
#
# Best parameters set found on development set:
#
# {'max_depth': 10}
#
# Grid scores on development set:
# 0.652 (+/-0.121) for {'max_depth': 3}
# 0.650 (+/-0.086) for {'max_depth': 4}
# 0.665 (+/-0.086) for {'max_depth': 5}
# 0.679 (+/-0.080) for {'max_depth': 6}
# 0.687 (+/-0.068) for {'max_depth': 7}
# 0.684 (+/-0.105) for {'max_depth': 8}
# 0.692 (+/-0.069) for {'max_depth': 9}
# 0.710 (+/-0.067) for {'max_depth': 10}

# %% [markdown]
# Re run the model with the optimal max_depth:

# %%
clf = RandomForestClassifier(n_estimators =100, oob_score=True, max_depth =9,
                            random_state =42)


clf.fit(X_train, y_train)
test_pred_random_forest = clf.predict(X_test)

train_accuracy = clf.score(X_train, y_train)
test_accuracy = clf.score(X_test, y_test)

print(f"The training score of the random forest classifier is : {train_accuracy:.3f}")
print(f"The test score of the random forest classifier is {test_accuracy:.3f}")

from sklearn import metrics

print (metrics.classification_report(y_test, test_pred_random_forest))
# Out:
# The training score of the random forest classifier is : 0.950
# The test score of the random forest classifier is 0.681
#               precision    recall  f1-score   support
#
#          bad       0.75      0.80      0.77       213
#         good       0.62      0.42      0.50        67
#         okay       0.62      0.65      0.63       200
#
#     accuracy                           0.68       480
#    macro avg       0.66      0.62      0.63       480
# weighted avg       0.68      0.68      0.68       480

# %% [markdown]
# ## Things to think about:
#
# 1. How has the model changed from the dummy model, to the original model, to the model with reduced features and to the model with the changed hyperparameters
# 2. How would the model change if we were to change the classification of the wines?
# 3. How do these results differ from the ones we obtained from the workshop results?
# 4. How could the results be improved further, if at all?
#
# ## You could push yourself by:
#
# 1. Applying this model to the white wine dataset used in the decision tree problem set
# 2. Combining the white wine and red wine dataset and seeing how the model performs
# 3. Finding your own dataset to perform the analysis on
